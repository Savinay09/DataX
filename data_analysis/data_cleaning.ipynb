# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import zipfile
import datetime
from sklearn.model_selection import train_test_split

# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set()
sns.set_context("talk")
import re

# %% [markdown]
# ## Original Dataset

# %%
df = pd.read_csv('raw_master.csv', names=['subject', 'from', 'date', 'to', 'label', 'thread'], encoding='iso-8859-1')
df['date'] = df['date'].apply(lambda x: pd.to_datetime(x, errors='coerce'))
df = df[df['date'].notna()]
df = df[1:]
df
# Out:
#                                                  subject  \
# 2                                                #ERROR!
# 3                                                #ERROR!
# 4                                                #ERROR!
# 5                                                #ERROR!
# 6         Complete your setup with the Slack desktop app
# ...                                                  ...
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
# 30535  =?utf-8?B?V2FudCB0byBnZXQgbW9yZSBmcm9tIFVPIFJl...
# 30536                       This fit has your name on it
#
#                                                     from  \
# 2           DailyDropout.fyi <dailydropout@substack.com>
# 3                                                #ERROR!
# 4                             neuvoo.com<job@neuvoo.com>
# 5      Ladder Newsletter <remoteworkforstudents@subst...
# 6                   "Slack" <no-reply@email.slackhq.com>
# ...                                                  ...
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
# 30535  "UO Rewards" <urbanoutfitters@e.urbanoutfitter...
# 30536                "Uniqlo USA" <email@usa.uniqlo.com>
#
#                             date  \
# 2      2021-02-09 17:41:10+00:00
# 3      2021-02-19 20:02:40+00:00
# 4      2021-02-08 13:38:06+00:00
# 5      2021-02-11 14:52:50+00:00
# 6      2021-01-21 11:02:05-06:00
# ...                          ...
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
# 30535  2021-02-09 22:25:17+00:00
# 30536  2021-02-17 08:10:07-08:00
#
#                                                     to  \
# 2                             tanishkumar@berkeley.edu
# 3                           <tanishkumar@berkeley.edu>
# 4                             tanishkumar@berkeley.edu
# 5                             tanishkumar@berkeley.edu
# 6                           <tanishkumar@berkeley.edu>
# ...                                                ...
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
# 30535  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30536                          <noorgill@berkeley.edu>
#
#                                                label               thread
# 2                   Inbox,Category Promotions,Unread  1691240491013211129
# 3                   Inbox,Category Promotions,Unread  1692155584056927524
# 4                   Inbox,Category Promotions,Unread  1691134489346807599
# 5                   Inbox,Category Promotions,Unread  1691411213622612924
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# ...                                              ...                  ...
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
# 30535            Inbox,Important,Category Promotions          1.69126E+18
# 30536  Archived,Important,Opened,Category Promotions          1.69196E+18
#
# [30535 rows x 6 columns]

# %% [markdown]
# ## Remove Duplicates

# %%
len(df.subject.unique())
# Out:
# 18367

# %% [markdown]
# We will compare the length of the dataset with the number of unique elements. Both are 14752.

# %%
df = df.drop_duplicates(subset=['subject'])
df
# Out:
#                                                  subject  \
# 2                                                #ERROR!
# 6         Complete your setup with the Slack desktop app
# 13                                Are you ready to play?
# 14     Gadabout - plus, Go behind the scenes of our n...
# 17     General Registration is now open for Winter/Sp...
# ...                                                  ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
# 30535  =?utf-8?B?V2FudCB0byBnZXQgbW9yZSBmcm9tIFVPIFJl...
#
#                                                     from  \
# 2           DailyDropout.fyi <dailydropout@substack.com>
# 6                   "Slack" <no-reply@email.slackhq.com>
# 13                                               #ERROR!
# 14                                               #ERROR!
# 17                      Mission College <nadler@wvm.edu>
# ...                                                  ...
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
# 30535  "UO Rewards" <urbanoutfitters@e.urbanoutfitter...
#
#                             date  \
# 2      2021-02-09 17:41:10+00:00
# 6      2021-01-21 11:02:05-06:00
# 13     2020-12-15 12:06:10-08:00
# 14     2021-02-01 04:14:58-06:00
# 17     2020-12-07 13:45:42-05:00
# ...                          ...
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
# 30535  2021-02-09 22:25:17+00:00
#
#                                                     to  \
# 2                             tanishkumar@berkeley.edu
# 6                           <tanishkumar@berkeley.edu>
# 13                            tanishkumar@berkeley.edu
# 14                          <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# ...                                                ...
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
# 30535  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
#
#                                                label               thread
# 2                   Inbox,Category Promotions,Unread  1691240491013211129
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 13                  Inbox,Category Promotions,Unread  1686176030552159651
# 14                  Inbox,Category Promotions,Unread  1690487487729257421
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# ...                                              ...                  ...
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
# 30535            Inbox,Important,Category Promotions          1.69126E+18
#
# [18367 rows x 6 columns]

# %% [markdown]
# ## Remove Errors and Unreadable UTFs

# %% [markdown]
# The first type of error happens when the entire string can not be decoded properly, which will show "#ERROR!". We will clean all rows with such errors.

# %%
df = df[df['subject'].str.contains("\#ERROR\!")==False]
df = df[df['from'].str.contains("\#ERROR\!")==False]
df
# Out:
#                                                  subject  \
# 6         Complete your setup with the Slack desktop app
# 17     General Registration is now open for Winter/Sp...
# 25     A global bank that doubles as a cybersecurity ...
# 27                                The next biggest thing
# 30                                 Read free for 30 days
# ...                                                  ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
# 30535  =?utf-8?B?V2FudCB0byBnZXQgbW9yZSBmcm9tIFVPIFJl...
#
#                                                     from  \
# 6                   "Slack" <no-reply@email.slackhq.com>
# 17                      Mission College <nadler@wvm.edu>
# 25                "Tricia at WayUp" <info@bb3.wayup.com>
# 27          DailyDropout.fyi <dailydropout@substack.com>
# 30                       Scribd <hello@hello.scribd.com>
# ...                                                  ...
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
# 30535  "UO Rewards" <urbanoutfitters@e.urbanoutfitter...
#
#                             date  \
# 6      2021-01-21 11:02:05-06:00
# 17     2020-12-07 13:45:42-05:00
# 25     2020-12-08 02:19:45+00:00
# 27     2021-01-29 23:09:33+00:00
# 30     2021-02-18 08:51:55+00:00
# ...                          ...
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
# 30535  2021-02-09 22:25:17+00:00
#
#                                                     to  \
# 6                           <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# 25           "Tanish Kumar" <tanishkumar@berkeley.edu>
# 27                            tanishkumar@berkeley.edu
# 30                            tanishkumar@berkeley.edu
# ...                                                ...
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
# 30535  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
#
#                                                label               thread
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# 25                  Inbox,Opened,Category Promotions  1685474756691839098
# 27                  Inbox,Category Promotions,Unread  1690264506723567323
# 30                  Inbox,Category Promotions,Unread  1692022410445336472
# ...                                              ...                  ...
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
# 30535            Inbox,Important,Category Promotions          1.69126E+18
#
# [17520 rows x 6 columns]

# %% [markdown]
# Another type of error happens on strings that contain emoticons, and they are usually decoded into a series of codes starting with either "UTF" or "utf". We will also clean all rows with this kind of codes.

# %%
df = df[df['subject'].str.contains('.*(UTF).*')==False]
df = df[df['subject'].str.contains('.*(utf).*')==False]
df
# Out:
# C:\Users\yang2\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\yang2\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                                  subject  \
# 6         Complete your setup with the Slack desktop app
# 17     General Registration is now open for Winter/Sp...
# 25     A global bank that doubles as a cybersecurity ...
# 27                                The next biggest thing
# 30                                 Read free for 30 days
# ...                                                  ...
# 30528  Now Hiring at Gilead Sciences, Daiichi Sankyo ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
#
#                                                     from  \
# 6                   "Slack" <no-reply@email.slackhq.com>
# 17                      Mission College <nadler@wvm.edu>
# 25                "Tricia at WayUp" <info@bb3.wayup.com>
# 27          DailyDropout.fyi <dailydropout@substack.com>
# 30                       Scribd <hello@hello.scribd.com>
# ...                                                  ...
# 30528           BioSpace <biospace_noreply@biospace.com>
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
#
#                             date  \
# 6      2021-01-21 11:02:05-06:00
# 17     2020-12-07 13:45:42-05:00
# 25     2020-12-08 02:19:45+00:00
# 27     2021-01-29 23:09:33+00:00
# 30     2021-02-18 08:51:55+00:00
# ...                          ...
# 30528  2020-10-28 12:16:34-05:00
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
#
#                                                     to  \
# 6                           <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# 25           "Tanish Kumar" <tanishkumar@berkeley.edu>
# 27                            tanishkumar@berkeley.edu
# 30                            tanishkumar@berkeley.edu
# ...                                                ...
# 30528                            noorgill@berkeley.edu
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
#
#                                                label               thread
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# 25                  Inbox,Opened,Category Promotions  1685474756691839098
# 27                  Inbox,Category Promotions,Unread  1690264506723567323
# 30                  Inbox,Category Promotions,Unread  1692022410445336472
# ...                                              ...                  ...
# 30528                      Inbox,Category Promotions          1.68182E+18
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
#
# [15486 rows x 6 columns]

# %% [markdown]
# The last type of error happens on some special characters, as they are replaced with unicode replacement characters "ï¿½" when they are extracted from our mailboxes. We will clean the rows with these characters by replacing such characters with empty strings.

# %%
df['subject'] = df['subject'].str.replace('ï¿½', '')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# The first feature is the labels of the email addresses that sent out these emails. As suggested by our mentor, these labels convey what kind of impressions these promotional email senders want to leave on us, which may be related to the emotions in the subject lines.

# %%
df['name'] = df['from'].str.split('<').str[0]
df['name'] = df['name'].str.replace('"', '')
df
# Out:
#                                                  subject  \
# 6         Complete your setup with the Slack desktop app
# 17     General Registration is now open for Winter/Sp...
# 25     A global bank that doubles as a cybersecurity ...
# 27                                The next biggest thing
# 30                                 Read free for 30 days
# ...                                                  ...
# 30528  Now Hiring at Gilead Sciences, Daiichi Sankyo ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
#
#                                                     from  \
# 6                   "Slack" <no-reply@email.slackhq.com>
# 17                      Mission College <nadler@wvm.edu>
# 25                "Tricia at WayUp" <info@bb3.wayup.com>
# 27          DailyDropout.fyi <dailydropout@substack.com>
# 30                       Scribd <hello@hello.scribd.com>
# ...                                                  ...
# 30528           BioSpace <biospace_noreply@biospace.com>
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
#
#                             date  \
# 6      2021-01-21 11:02:05-06:00
# 17     2020-12-07 13:45:42-05:00
# 25     2020-12-08 02:19:45+00:00
# 27     2021-01-29 23:09:33+00:00
# 30     2021-02-18 08:51:55+00:00
# ...                          ...
# 30528  2020-10-28 12:16:34-05:00
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
#
#                                                     to  \
# 6                           <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# 25           "Tanish Kumar" <tanishkumar@berkeley.edu>
# 27                            tanishkumar@berkeley.edu
# 30                            tanishkumar@berkeley.edu
# ...                                                ...
# 30528                            noorgill@berkeley.edu
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
#
#                                                label               thread  \
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# 25                  Inbox,Opened,Category Promotions  1685474756691839098
# 27                  Inbox,Category Promotions,Unread  1690264506723567323
# 30                  Inbox,Category Promotions,Unread  1692022410445336472
# ...                                              ...                  ...
# 30528                      Inbox,Category Promotions          1.68182E+18
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
#
#                     name
# 6                 Slack
# 17      Mission College
# 25      Tricia at WayUp
# 27     DailyDropout.fyi
# 30               Scribd
# ...                  ...
# 30528          BioSpace
# 30531  Taco from Trello
# 30532         Hanes.com
# 30533  Urban Outfitters
# 30534        Let's Roam
#
# [15486 rows x 7 columns]

# %% [markdown]
# The second group of features is about the time that these emails are sent. We converted the dates in the "date" column to datetime objects and extracted the exact times, the hours, and the months during which the emails are sent. The exact times are kept in the time zone that the receivers are in, which better match with the purposes of these emails.

# %%
df['date_utc'] = pd.to_datetime(df['date'], format="%Y%m%d %H:%M:%S.%f", utc=True)
df['time'] = [x.strftime("%H:%M:%S") for x in df['date']]
df['hour'] = [re.findall('[0-9]{2}',x)[0] for x in df['time']]
df['month'] = pd.DatetimeIndex(df['date_utc']).month
df
# Out:
#                                                  subject  \
# 6         Complete your setup with the Slack desktop app
# 17     General Registration is now open for Winter/Sp...
# 25     A global bank that doubles as a cybersecurity ...
# 27                                The next biggest thing
# 30                                 Read free for 30 days
# ...                                                  ...
# 30528  Now Hiring at Gilead Sciences, Daiichi Sankyo ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
#
#                                                     from  \
# 6                   "Slack" <no-reply@email.slackhq.com>
# 17                      Mission College <nadler@wvm.edu>
# 25                "Tricia at WayUp" <info@bb3.wayup.com>
# 27          DailyDropout.fyi <dailydropout@substack.com>
# 30                       Scribd <hello@hello.scribd.com>
# ...                                                  ...
# 30528           BioSpace <biospace_noreply@biospace.com>
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
#
#                             date  \
# 6      2021-01-21 11:02:05-06:00
# 17     2020-12-07 13:45:42-05:00
# 25     2020-12-08 02:19:45+00:00
# 27     2021-01-29 23:09:33+00:00
# 30     2021-02-18 08:51:55+00:00
# ...                          ...
# 30528  2020-10-28 12:16:34-05:00
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
#
#                                                     to  \
# 6                           <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# 25           "Tanish Kumar" <tanishkumar@berkeley.edu>
# 27                            tanishkumar@berkeley.edu
# 30                            tanishkumar@berkeley.edu
# ...                                                ...
# 30528                            noorgill@berkeley.edu
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
#
#                                                label               thread  \
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# 25                  Inbox,Opened,Category Promotions  1685474756691839098
# 27                  Inbox,Category Promotions,Unread  1690264506723567323
# 30                  Inbox,Category Promotions,Unread  1692022410445336472
# ...                                              ...                  ...
# 30528                      Inbox,Category Promotions          1.68182E+18
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
#
#                     name                  date_utc      time hour  month
# 6                 Slack  2021-01-21 17:02:05+00:00  11:02:05   11      1
# 17      Mission College  2020-12-07 18:45:42+00:00  13:45:42   13     12
# 25      Tricia at WayUp  2020-12-08 02:19:45+00:00  02:19:45   02     12
# 27     DailyDropout.fyi  2021-01-29 23:09:33+00:00  23:09:33   23      1
# 30               Scribd  2021-02-18 08:51:55+00:00  08:51:55   08      2
# ...                  ...                       ...       ...  ...    ...
# 30528          BioSpace  2020-10-28 17:16:34+00:00  12:16:34   12     10
# 30531  Taco from Trello  2020-10-01 15:46:29+00:00  15:46:29   15     10
# 30532         Hanes.com  2021-02-23 12:11:30+00:00  07:11:30   07      2
# 30533  Urban Outfitters  2021-03-17 16:04:08+00:00  16:04:08   16      3
# 30534        Let's Roam  2021-02-18 18:35:54+00:00  18:35:54   18      2
#
# [15486 rows x 11 columns]

# %% [markdown]
# We also think that the use of punctuations, such as question marks and exclaimation marks may convey strong emotions in the subject lines, so we extracted the number of these punctuations used as well.

# %%
df['num_qm'] = df['subject'].str.count('\\?')
df['num_em'] = df['subject'].str.count('\\!')
df
# Out:
#                                                  subject  \
# 6         Complete your setup with the Slack desktop app
# 17     General Registration is now open for Winter/Sp...
# 25     A global bank that doubles as a cybersecurity ...
# 27                                The next biggest thing
# 30                                 Read free for 30 days
# ...                                                  ...
# 30528  Now Hiring at Gilead Sciences, Daiichi Sankyo ...
# 30531              How to pretend to be a morning person
# 30532        Find out why Beefy-T Tees are all the rave!
# 30533      swimwear & sandals & beach towels & sunscreen
# 30534                        You want WHAT?! No problem.
#
#                                                     from  \
# 6                   "Slack" <no-reply@email.slackhq.com>
# 17                      Mission College <nadler@wvm.edu>
# 25                "Tricia at WayUp" <info@bb3.wayup.com>
# 27          DailyDropout.fyi <dailydropout@substack.com>
# 30                       Scribd <hello@hello.scribd.com>
# ...                                                  ...
# 30528           BioSpace <biospace_noreply@biospace.com>
# 30531               "Taco from Trello" <taco@trello.com>
# 30532                 "Hanes.com" <hanes@mail.hanes.com>
# 30533  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30534  "Let's Roam" <support@letsroamscavengerhunts.com>
#
#                             date  \
# 6      2021-01-21 11:02:05-06:00
# 17     2020-12-07 13:45:42-05:00
# 25     2020-12-08 02:19:45+00:00
# 27     2021-01-29 23:09:33+00:00
# 30     2021-02-18 08:51:55+00:00
# ...                          ...
# 30528  2020-10-28 12:16:34-05:00
# 30531  2020-10-01 15:46:29+00:00
# 30532  2021-02-23 07:11:30-05:00
# 30533  2021-03-17 16:04:08+00:00
# 30534  2021-02-18 18:35:54+00:00
#
#                                                     to  \
# 6                           <tanishkumar@berkeley.edu>
# 17                            tanishkumar@berkeley.edu
# 25           "Tanish Kumar" <tanishkumar@berkeley.edu>
# 27                            tanishkumar@berkeley.edu
# 30                            tanishkumar@berkeley.edu
# ...                                                ...
# 30528                            noorgill@berkeley.edu
# 30531               "noorgill" <noorgill@berkeley.edu>
# 30532                            noorgill@berkeley.edu
# 30533  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30534                            noorgill@berkeley.edu
#
#                                                label               thread  \
# 6         Inbox,Important,Category Promotions,Unread  1689516575768603440
# 17                  Inbox,Category Promotions,Unread  1685446190686767938
# 25                  Inbox,Opened,Category Promotions  1685474756691839098
# 27                  Inbox,Category Promotions,Unread  1690264506723567323
# 30                  Inbox,Category Promotions,Unread  1692022410445336472
# ...                                              ...                  ...
# 30528                      Inbox,Category Promotions          1.68182E+18
# 30531                      Inbox,Category Promotions          1.67936E+18
# 30532  Archived,Important,Opened,Category Promotions          1.69249E+18
# 30533               Trash,Category Promotions,Unread           1.6945E+18
# 30534            Inbox,Important,Category Promotions          1.69206E+18
#
#                     name                  date_utc      time hour  month  \
# 6                 Slack  2021-01-21 17:02:05+00:00  11:02:05   11      1
# 17      Mission College  2020-12-07 18:45:42+00:00  13:45:42   13     12
# 25      Tricia at WayUp  2020-12-08 02:19:45+00:00  02:19:45   02     12
# 27     DailyDropout.fyi  2021-01-29 23:09:33+00:00  23:09:33   23      1
# 30               Scribd  2021-02-18 08:51:55+00:00  08:51:55   08      2
# ...                  ...                       ...       ...  ...    ...
# 30528          BioSpace  2020-10-28 17:16:34+00:00  12:16:34   12     10
# 30531  Taco from Trello  2020-10-01 15:46:29+00:00  15:46:29   15     10
# 30532         Hanes.com  2021-02-23 12:11:30+00:00  07:11:30   07      2
# 30533  Urban Outfitters  2021-03-17 16:04:08+00:00  16:04:08   16      3
# 30534        Let's Roam  2021-02-18 18:35:54+00:00  18:35:54   18      2
#
#        num_qm  num_em
# 6           0       0
# 17          0       1
# 25          1       1
# 27          0       0
# 30          0       0
# ...       ...     ...
# 30528       0       0
# 30531       0       0
# 30532       0       1
# 30533       0       0
# 30534       1       1
#
# [15486 rows x 13 columns]

# %% [markdown]
# The last feature, even though it is minor compared to others, may also help with predictions. We think the use of hashtags may also expresses specific emotions, so we set whether the subject line contains a hashtag as another feature.

# %%
df['hashtag'] = df['subject'].str.contains(r'#[a-zA-z]').astype(int)
df[df['hashtag'] == 1]
# Out:
#                                                  subject  \
# 463                                Let's get you #hired.
# 1406   Now Available: #FauxFilter Luminous Matte Foun...
# 2264   #StyleWithBITE: Upswing Full-Volume Mascara ed...
# 2334                         Ready for more #FauxFilter?
# 4072                Happy #CyberMonday! 35% off SITEWIDE
# ...                                                  ...
# 26183  #Trending PATRICK TA, HUDA BEAUTY & ONES/SIZE ...
# 27234  #SHEIN 1111 is on: FREE SHIPPING for Singles' Day
# 27870              Will you answer the call #turntocold?
# 28224                       Head to toe in BDG | #BDG365
# 30065                       #LifeAtAmgen during Covid-19
#
#                                                     from  \
# 463                "The WayUp Team" <info@bb3.wayup.com>
# 1406                  Huda Beauty <hello@hudabeauty.com>
# 2264                BITE Beauty <noreply@bitebeauty.com>
# 2334                  Huda Beauty <hello@hudabeauty.com>
# 4072                BITE Beauty <noreply@bitebeauty.com>
# ...                                                  ...
# 26183                 Sephora  <shop@beauty.sephora.com>
# 27234  =?UTF-8?B?U0hFSU4=?= <shein@market.sheinmail.com>
# 27870                 "Hanes.com" <hanes@mail.hanes.com>
# 28224  "Urban Outfitters" <urbanoutfitters@e.urbanout...
# 30065  Amgen Talent Community <amgentalentcommunity@a...
#
#                             date  \
# 463    2020-11-26 01:15:32+00:00
# 1406   2021-01-24 20:47:41+00:00
# 2264   2021-01-08 23:31:08+00:00
# 2334   2021-01-19 18:05:16+00:00
# 4072   2020-11-30 13:46:23+00:00
# ...                          ...
# 26183  2021-01-02 17:21:30+00:00
# 27234  2020-11-11 08:40:49-08:00
# 27870  2021-04-02 15:55:17-04:00
# 28224  2020-06-09 23:11:02+00:00
# 30065  2020-05-06 15:17:44+00:00
#
#                                                     to  \
# 463                      "" <tanishkumar@berkeley.edu>
# 1406     "noorgill08@gmail.com" <noorgill08@gmail.com>
# 2264     "noorgill08@gmail.com" <noorgill08@gmail.com>
# 2334     "noorgill08@gmail.com" <noorgill08@gmail.com>
# 4072     "noorgill08@gmail.com" <noorgill08@gmail.com>
# ...                                                ...
# 26183                            noorgill@berkeley.edu
# 27234                            noorgill@berkeley.edu
# 27870                            noorgill@berkeley.edu
# 28224  "noorgill@berkeley.edu" <noorgill@berkeley.edu>
# 30065                            noorgill@berkeley.edu
#
#                                                label               thread  \
# 463                 Inbox,Category Promotions,Unread  1684383552631345154
# 1406                       Inbox,Category Promotions  1689802518682241553
# 2264             Archived,Opened,Category Promotions  1688363255481334067
# 2334                       Inbox,Category Promotions  1689339315977285552
# 4072                       Inbox,Category Promotions  1684793183123885193
# ...                                              ...                  ...
# 26183            Archived,Opened,Category Promotions           1.6878E+18
# 27234            Archived,Opened,Category Promotions          1.68308E+18
# 27870               Trash,Category Promotions,Unread          1.69596E+18
# 28224     Inbox,Important,Opened,Category Promotions          1.66906E+18
# 30065  Archived,Important,Opened,Category Promotions          1.66595E+18
#
#                           name                  date_utc      time hour  \
# 463            The WayUp Team  2020-11-26 01:15:32+00:00  01:15:32   01
# 1406              Huda Beauty  2021-01-24 20:47:41+00:00  20:47:41   20
# 2264              BITE Beauty  2021-01-08 23:31:08+00:00  23:31:08   23
# 2334              Huda Beauty  2021-01-19 18:05:16+00:00  18:05:16   18
# 4072              BITE Beauty  2020-11-30 13:46:23+00:00  13:46:23   13
# ...                        ...                       ...       ...  ...
# 26183                Sephora   2021-01-02 17:21:30+00:00  17:21:30   17
# 27234    =?UTF-8?B?U0hFSU4=?=  2020-11-11 16:40:49+00:00  08:40:49   08
# 27870               Hanes.com  2021-04-02 19:55:17+00:00  15:55:17   15
# 28224        Urban Outfitters  2020-06-09 23:11:02+00:00  23:11:02   23
# 30065  Amgen Talent Community  2020-05-06 15:17:44+00:00  15:17:44   15
#
#        month  num_qm  num_em  hashtag
# 463       11       0       0        1
# 1406       1       0       0        1
# 2264       1       0       0        1
# 2334       1       1       0        1
# 4072      11       0       1        1
# ...      ...     ...     ...      ...
# 26183      1       0       0        1
# 27234     11       0       0        1
# 27870      4       1       0        1
# 28224      6       0       0        1
# 30065      5       0       0        1
#
# [72 rows x 14 columns]

# %% [markdown]
# ## New Dataset

# %%
df.to_csv('Cleaned Dataset.csv', index=False)

# %% [markdown]
# ## Train Test Split

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=0)
df_train.to_csv('Training Set.csv', index=False)
df_test.to_csv('Test Set.csv', index=False)
